# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple']

print(fruits)
# Out:
# ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple']

# %%
fruits[0]
# Out:
# 'orange'

# %%
rainbow_split = '빨-주-노-초-파-남-보'
print(rainbow_split.split('-'))
# Out:
# ['빨', '주', '노', '초', '파', '남', '보']

# %%
list1 = []
list2 = list()

print(list1 == list2)
print(type(list1))
print(type(list2))
# Out:
# True
# <class 'list'>
# <class 'list'>

# %%
list3 = list('hello')
print(list3)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
safari_list = ['Bear','Koala','Gorlla','Squirrel']
another_safari_list = ['Monkey','Tiger','Wolf']

print(safari_list+another_safari_list)
# Out:
# ['Bear', 'Koala', 'Gorlla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf']

# %%
safari_list = ['Bear','Koala','Gorlla','Squirrel']
result= safari_list * 4

print(result)
# Out:
# ['Bear', 'Koala', 'Gorlla', 'Squirrel', 'Bear', 'Koala', 'Gorlla', 'Squirrel', 'Bear', 'Koala', 'Gorlla', 'Squirrel', 'Bear', 'Koala', 'Gorlla', 'Squirrel']

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple']

print("apple:", fruits.count('apple'))
# Out:
# apple: 2

# %%
print("test:", fruits.count('test'))
# Out:
# test: 0

# %%
print("index:", fruits.index('apple'))
# Out:
# index: 1

# %%
print("index:", fruits.index('apple1'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print("index:", fruits.index('apple1'))
#
# ValueError: list.index(x): x not in list

# %%
print("index:", fruits.index('apple',3))
# Out:
# index: 5

# %%
fruits.reverse()
print(fruits)
# Out:
# ['sweet lemon', 'rainbow fruit', 'pineapple', 'orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'Monkey banana', 'monkey banana', 'monkey banana']

# %%
lst = [1,2,3,4,5]
lst.reverse()
print(lst)
# Out:
# [5, 4, 3, 2, 1]

# %%
lst = [1,2,3,4,5]
lst2 = reversed(lst)
print(lst)
print(lst2)

for x in lst2:
    print(x, end=' ')
# Out:
# [1, 2, 3, 4, 5]
# <list_reverseiterator object at 0x00000256046BDB40>
# 5 4 3 2 1

# %%
fruits.append('pineapple')
print(fruits)
# Out:
# ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'pineapple']

# %%
fruits.extend(['rainbow fruit','sweet lemon'])

print(fruits)
# Out:
# ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'pineapple', 'rainbow fruit', 'sweet lemon']

# %%
fruits
# Out:
# ['orange',
#  'apple',
#  'pear',
#  'banana',
#  'kiwi',
#  'apple',
#  'pineapple',
#  'rainbow fruit',
#  'sweet lemon']

# %%
fruits.insert(0,'monkey banana')
print(fruits)
# Out:
# ['monkey banana', 'orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'pineapple', 'rainbow fruit', 'sweet lemon']

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'apple', 'banana', 'kiwi', 'monkey banana', 'orange', 'pear', 'pineapple', 'rainbow fruit', 'sweet lemon']

# %%
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['sweet lemon', 'rainbow fruit', 'pineapple', 'pear', 'orange', 'monkey banana', 'kiwi', 'banana', 'apple', 'apple']

# %%
fruits.sort(key=len)
print(fruits)
# Out:
# ['pear', 'kiwi', 'apple', 'apple', 'orange', 'banana', 'pineapple', 'sweet lemon', 'rainbow fruit', 'monkey banana']

# %%
fruits.sort(key=lambda x:(len(x),x))
print(fruits)
# Out:
# ['kiwi', 'pear', 'apple', 'apple', 'banana', 'orange', 'pineapple', 'sweet lemon', 'monkey banana', 'rainbow fruit']

# %%
temp = fruits.remove('kiwi')
print(temp)
print(fruits)
# Out:
# None
# ['pear', 'apple', 'apple', 'banana', 'orange', 'pineapple', 'sweet lemon', 'monkey banana', 'rainbow fruit']

# %%
lst = [2,3,5,1,4]
lst2 = sorted(lst)

print(lst)
print(lst2)
# Out:
# [2, 3, 5, 1, 4]
# [1, 2, 3, 4, 5]

# %%
temp = fruits.pop()
print(temp)
print(fruits)
# Out:
# rainbow fruit
# ['pear', 'apple', 'apple', 'banana', 'orange', 'pineapple', 'sweet lemon', 'monkey banana']

# %%
plates = ['plate1','plate2']

plates.append('plate3')
plates.append('plate4')

print(plates)
# Out:
# ['plate1', 'plate2', 'plate3', 'plate4']

# %%
print(plates.pop())
print(plates)
print(plates.pop())
print(plates.pop())
print(plates)
# Out:
# plate4
# ['plate1', 'plate2', 'plate3']
# plate3
# plate2
# ['plate1']

# %%
abclist = ['A','B','C','D','E','F']
print(abclist)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
del abclist[0]
print(abclist)
# Out:
# ['B', 'C', 'D', 'E', 'F']

# %%
del abclist[1:3] # [시작:끝-1]
print(abclist)
# Out:
# ['B', 'E', 'F']

# %%
del abclist[:]
print(abclist)
# Out:
# []

# %%
abclist = ['A','B','C','D','E','F']
del abclist
print(abclist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 3
#       1 abclist = ['A','B','C','D','E','F']
#       2 del abclist
# ----> 3 print(abclist)
#
# NameError: name 'abclist' is not defined

# %%
from collections import deque

dq = deque()

dq.append('a')
dq.append('b')
dq.append('c')

print(dq)
# Out:
# deque(['a', 'b', 'c'])

# %%
dq.appendleft('x')
print(dq)
# Out:
# deque(['x', 'a', 'b', 'c'])

# %%
value = dq.pop()
print(value)

left_value = dq.popleft()
print(left_value)

print(dq)
# Out:
# c
# x
# deque(['a', 'b'])

# %%
tuples = (1,2,'hello')
print(tuples)
print(tuples[0])
print(tuples[1])
print(tuples[2])
# Out:
# (1, 2, 'hello')
# 1
# 2
# hello

# %%
tuples = (1,2,'hello'),('test',1,2,3,4)
print(tuples)
print(tuples[0])
print(tuples[1][0]) # test
# Out:
# ((1, 2, 'hello'), ('test', 1, 2, 3, 4))
# (1, 2, 'hello')
# test

# %%
no_wrap_tuples = 1, 2, 3
print(no_wrap_tuples)
# Out:
# (1, 2, 3)

# %%
tuples = (1,2,'hello'),('test',1,2,3,4)
tuple[0] = (1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 tuples = (1,2,'hello'),('test',1,2,3,4)
# ----> 2 tuple[0] = (1,2,3,4)
#
# TypeError: 'type' object does not support item assignment

# %%
testList = (1,2,3,4)
print(id(testList))

testList = (3,4,5)
print(id(testList))
# Out:
# 2568469839632
# 2568471156016

# %%
safari_tuple=('bear','koala','gorilla','squirrel')
another_safari_tuple = ('Monkey','Tiger','Wolf')

result = safari_tuple + another_safari_tuple

print(result)
# Out:
# ('bear', 'koala', 'gorilla', 'squirrel', 'Monkey', 'Tiger', 'Wolf')

# %%
print(safari_tuple * 3)
# Out:
# ('bear', 'koala', 'gorilla', 'squirrel', 'bear', 'koala', 'gorilla', 'squirrel', 'bear', 'koala', 'gorilla', 'squirrel')

# %%
print(len(safari_tuple + another_safari_tuple))
# Out:
# 7

# %%
location = ['서울','부산','인천','광주','울산']
print(location[-5])
# Out:
# 서울

# %%
address = '대한민국 서울시 서초구'
print(address[5:8])
# Out:
# 서울시

# %%
location = ['서울','부산','인천','광주','울산']
print(location[2:5])
print(location[2:])
# Out:
# ['인천', '광주', '울산']
# ['인천', '광주', '울산']

# %%
address = '대한민국 서울시 서초구'
print(address[9:])
print(address[-3:])
print(address[1:12:4])
print(address[::-1])
# Out:
# 서초구
# 서초구
# 한서서
# 구초서 시울서 국민한대

# %%
location = ['서울','부산','인천','광주','울산']
print(location[-2:])
print(location[-4:])
print(location[1:-1:2])
print(location[2::-1])
# Out:
# ['광주', '울산']
# ['부산', '인천', '광주', '울산']
# ['부산', '광주']
# ['인천', '부산', '서울']

# %%
nation = ('대한민국', '미국', '중국', '일본', '프랑스')
print(nation[1:]) # 미국,중국,일본,프랑스
print(nation[-3:]) # 중국,일본,프랑스
print(nation[1:5:2]) # 미국,일본
print(nation[::-1]) # 프랑스,일본,중국,미국,대한민국
# Out:
# ('미국', '중국', '일본', '프랑스')
# ('중국', '일본', '프랑스')
# ('미국', '일본')
# ('프랑스', '일본', '중국', '미국', '대한민국')

# %%
nation = ('대한민국', '미국', '중국', '일본', '프랑스',('대한민국','미국'))

print(nation[5][1])
# Out:
# 미국

# %%
address = '대한민국 서울시 서초구'
print(len(address)) # 12

location = ['서울','부산','인천','광주','울산']
print(len(location)) # 5

nation = ('대한민국', '미국', '중국', '일본', '프랑스',('대한민국','미국'))
print(len(nation)) # 6
# Out:
# 12
# 5
# 6
