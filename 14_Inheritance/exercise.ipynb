# %%
class Person:
    national  = 'korea'
    
    def greeting(self):
        return "Hello. this is Python"
    

class Student(Person):
    pass

student = Student()

print(student.national)
print(student.greeting())
# Out:
# korea
# Hello. this is Python

# %%
class Person:
    national  = 'korea'
    
    def greeting(self):
        return "Hello. this is Python"

class Learner:
    def greeting(self):
        return 'Hello I am Learner'
    
    def learn(self):
        return 'I am learning Python'

class Student(Person, Learner):
    pass

student = Student()

print(student.greeting())
print(student.learn())
# Out:
# Hello. this is Python
# I am learning Python

# %%
import learning_pesrson

class Person:
    national  = 'korea'
    
    def greeting(self):
        return "Hello. this is Python"
    
class Student(Person,learning_pesrson.learner):
    pass

student = Student()

print(student.greeting())
print(student.learn())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       6     def greeting(self):
#       7         return "Hello. this is Python"
# ----> 9 class Student(Person,learning_pesrson.learner):
#      10     pass
#      12 student = Student()
#
# AttributeError: module 'learning_pesrson' has no attribute 'learner'

# %%
class Person:
    national = 'korea'
    
    def greeting(self):
        return 'Hello. This is Python'
    
class Learner(Person):
    def __init__(self, subject):
        self.subject = subject
        
    def learn(self):
        return 'I am learning ' + self.subject
    
class Student(Learner):
    def __init__(self, name, subject):
        Learner.__init__(self, subject)
        self.name = name
    
    def greeting(self):
        return "Hello. My name is " + self.name
    
student = Student('다람쥐', 'python')
print(student.greeting())
print(student.learn())
# Out:
# Hello. My name is 다람쥐
# I am learning python

# %%
# 부모클래스 선언
class Person:
    def __init__(self, name, phone=None):
        self.name = name
        self.phone = phone
    # 인스턴스 중복시 실행되는 메서드
    def __str__(self):
        return f"person {self.name}, {self.phone}"
# 자식 클래스 선언
class Employee(Person):
    def __init__(self, name, phone, position, Salary):
        
        # Person.__init__(sellf, name, phone)
        super().__init__(name, phone)
        self.position = position
        self.salary = Salary
        
p1 = Person('홍길동', '010-1234-5678')
print(p1.name)
print(p1)      

m1 = Employee('호랑이', '010-9874-3214', '사원', '20_000_000')
m2 = Employee('돼지','010-4587-5657', '대리','22_000_000')

# m1의 이름과 직책 출력
print(m1.name, m1.position)
# m1의 인스턴스 호출해서 실행되는 메서드 출력
print(m1)
print(m2.name, m2.position)
print(m2)
# Out:
# 홍길동
# person 홍길동, 010-1234-5678
# 호랑이 사원
# person 호랑이, 010-9874-3214
# 돼지 대리
# person 돼지, 010-4587-5657

# %%
class Animal:
    def do(self):
        print("동물")
class Dog(Animal):
    def do(self):
        print("멍멍")
class Duck(Animal):
    def do(self):
        print("꽥꽥")
class Fish(Animal):
    pass

for each in (Dog(),Duck(),Fish()):
    each.do()
# Out:
# 멍멍
# 꽥꽥
# 동물

# %%
class Alarm:
    def do(self):
        print("따르릉")
        
for each in (Dog(),Duck(),Fish(),Alarm()):
    each.do()
# Out:
# 멍멍
# 꽥꽥
# 동물
# 따르릉
