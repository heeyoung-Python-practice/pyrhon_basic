# %%
import ohgraffers_module

print(ohgraffers_module.ohgiraffers)
print(ohgraffers_module.tiger())
print(ohgraffers_module.gorilla())
print(ohgraffers_module.pig())
# Out:
# 국내최고 IT 전문교육 강사팀
# 어흥
# 크릉
# 꿀꿀

# %%
from ohgraffers_module import ohgiraffers, gorilla

print(ohgiraffers)
print(gorilla())
# Out:
# 국내최고 IT 전문교육 강사팀
# 크릉

# %%
import ohgraffers_module as OG

print(OG.ohgiraffers)
print(OG.gorilla())
# Out:
# 국내최고 IT 전문교육 강사팀
# 크릉

# %%
from ohgraffers_module import ohgiraffers as oh, gorilla as gol

print(oh)
print(gol())
# Out:
# 국내최고 IT 전문교육 강사팀
# 크릉

# %%
import math

print(math.sqrt(16))
print(math.factorial(5))
print(math.pi)
# Out:
# 4.0
# 120
# 3.141592653589793
