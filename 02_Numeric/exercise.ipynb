# %%
num1 = 1
num2 = -1

print(type(num1))
print(type(num2))
print(type(123))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
num3 = 3.14
num4 = 1.0

print(type(num3))
print(type(num4))
# Out:
# <class 'float'>
# <class 'float'>

# %%
num5 = 3 + 4j
print(type(num5))
# Out:
# <class 'complex'>

# %%
# 정수 진법별 접두사
# 2진수(0, 1) : 0b
# 9진수(0 ~ 7) : 0o
# 16진수(0 ~ 15) : 0x

a = 100
print(a)

b = 0o23
print(b)

c = 0xff
print(c)
# Out:
# 100
# 19
# 255

# %%
# 정수의 최대값

import sys
print(sys.maxsize)
# Out:
# 9223372036854775807

# %%
# 지수 표현식
# 4.24E10 => 4.24 * 10*10. 4.24e-10은 4.24 * 10*-10
a = 4.24E3      
b = 4.24e-3
print(a)
print(b)
# Out:
# 4240.0
# 0.00424

# %%
print(complex(1,1)) # 1+1j
# Out:
# (1+1j)

# %%
num1 = 10
num2 = 3

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
# Out:
# 13
# 7
# 30
# 3.3333333333333335

# %%
num3 = 10
num4 = 0.1

print(num3 + num4)
print(num3 - num4)
print(num3 * num4)
print(num3 / num4)
# Out:
# 10.1
# 9.9
# 1.0
# 100.0

# %%
num1 = 11
num2 = 7

print(num1 % num2)
# Out:
# 4

# %%
num1 = 11
num2 = 7

print(num1 // num2)
# Out:
# 1

# %%
base = 9
exponent = 3
result = base ** exponent

print(result)
# Out:
# 729

# %%
bool1 = True
bool2 = False

print(bool1)
print(bool2)

print(type(bool1))
print(type(bool2))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %%
print(1 == 3)   # False
print('ohgiraffers' != 'Ohgiraffers')   # True
print(100 > 90) # True
print(0 >= 1)   # False
print(0 <= 1)   #True
# Out:
# False
# True
# True
# False
# True

# %%
# Out:
# <class 'complex'>
# 5j

# %%
print('a' > 'A')
print('a' < 'A')
# Out:
# True
# False

# %%
print(1 != 3 and 100 > 99 and True)
print(1 != 3 and 100 > 99 and 100 < 99)
# Out:
# True
# False

# %%
print(1 != 3 or 100 > 99 or True)
print(1 != 3 or 100 > 99 or 100 < 99)
print(1 == 3 or False or 100 < 99)
# Out:
# True
# True
# False

# %%
print(not 'ohgiraffers' == 'Ohgiraffers')
print(not True)
print('ohgiraffers' != 'Ohgiraffers')
# Out:
# True
# False
# True

# %%
my_name = 'jung'

# %%
print("""
      한줄이다
      두줄이다
      세줄이다
      """)
# Out:
#       한줄이다
#       두줄이다
#       세줄이다

# %%
# 여기다가 1줄 주석을 씁니다
""" 개발에 대한 참고
이 함수는 나이를 반환하는 함수입니다.

입력값 : 문자형
출력값 : 숫자형
"""
# Out:
# ' 개발에 대한 참고\n이 함수는 나이를 반환하는 함수입니다.\n\n입력값 : 문자형\n출력값 : 숫자형\n'

# %%
greeting = "반갑습니"
name = "다람쥐"

print(greeting + name)
print(greeting + '다. ' + name + '입니다!')
# Out:
# 반갑습니다람쥐
# 반갑습니다. 다람쥐입니다!

# %%
name = "jung"
print(900 + "살" + name + "입니다.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 name = "jung"
# ----> 2 print(900 + "살" + name + "입니다.")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(str(900) + "살" + name + "입니다.")
# Out:
# 900살jung입니다.

# %%
subject = 'python'
"무슨 일이든 세 번만 외쳐보자." + (" 나는 " + subject + "을 잘할 수 있다!") * 3
# Out:
# '무슨 일이든 세 번만 외쳐보자. 나는 python을 잘할 수 있다! 나는 python을 잘할 수 있다! 나는 python을 잘할 수 있다!'

# %%
enrole_date = '2024/12/10'
rep_enrole_date = enrole_date.replace("/","-")

print(enrole_date)
print(rep_enrole_date)
# Out:
# 2024/12/10
# 2024-12-10

# %%
origin = 'ohgiraffers'
with_white_space = '           oh giraffers    '
print(with_white_space.strip())
# Out:
# oh giraffers

# %%
print(with_white_space.strip('           o'))
# Out:
# h giraffers

# %%
print(origin.strip('os'))
# Out:
# hgiraffer

# %%
print(origin.lstrip('os'))
# Out:
# hgiraffers

# %%
print(origin)
# Out:
# ohgiraffers

# %%
orgin_str = 'hELLO wOLRD'

print(orgin_str.upper())
print(orgin_str.lower())
print(orgin_str.capitalize())
print(orgin_str.swapcase())
print(orgin_str.title())
# Out:
# HELLO WOLRD
# hello wolrd
# Hello wolrd
# Hello Wolrd
# Hello Wolrd

# %%
x = 10
print("x is %d" %x)

y = "code"
print("y is %s" %y)
# Out:
# x is 10
# y is code

# %%
x, u = 10, "code"

print("x is {0}".format(x))
print("x is {0} y is {1}".format(x, y))
print("x is {new_x} y is {new_y}".format(new_x=x, new_y=y))
# Out:
# x is 10
# x is 10 y is code
# x is 10 y is code

# %%
teacher_name = "카피바라"

print(f"안녕하세요. 오늘부터 여러분과 함께 공부할 {teacher_name} 강사 입니다")
# Out:
# 안녕하세요. 오늘부터 여러분과 함께 공부할 카피바라 강사 입니다

# %%
# 한줄 주석이다
# 이렇게 그냥 작성하면 에러가 발생합니다.

print('이건 해석하구요')
# print('이건 해석하지 않습니다.')
# Out:
# 이건 해석하구요

# %%
print(True + 3)
print(3 + 5.0)

print(type(True + 3))
print(type(3 + 5.0))
# Out:
# 4
# 8.0
# <class 'int'>
# <class 'float'>

# %%
#print(3 + "5")
print(type(3))
print(type("5"))
print(3)
print("5")
# Out:
# <class 'int'>
# <class 'str'>
# 3
# 5

# %%
print(int('3') + 4)
# Out:
# 7

# %%
print(float('3'))
print(type('3'))
print(type(float('3')))
# Out:
# 3.0
# <class 'str'>
# <class 'float'>

# %%
print(str(1))
print(str(1.0))
print(str({1,2,3}))

print(type(str(1)))
print(type(str(1.0)))
print(type(str({1,2,3})))
# Out:
# 1
# 1.0
# {1, 2, 3}
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(list('ohgiraffers'))
# Out:
# ['o', 'h', 'g', 'i', 'r', 'a', 'f', 'f', 'e', 'r', 's']

# %%
print(list({1, 2, 3, 4, 5}))
# Out:
# [1, 2, 3, 4, 5]

# %%
print(
    list(
        {   "1": "사랑하는 우리반",
            "2": "열심히 공부하십시오.",
            "3": "선생님 부탁입니다."
        }
    )
)
# Out:
# ['1', '2', '3']
