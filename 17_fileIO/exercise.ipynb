# %%
# dev 폴더 생성
import os

os.makedirs('C:/Users/Playdata/python/python_basic/17_fileIO/dev',exist_ok=True)

# %%
f=open("dev/frog_song.txt","w")

# %%
# 파일 한글 깨짐시 utf-8 인코딩한다
f=open('dev/frog_song.txt','r',encoding='utf-8')
data = f.read()
print(data)
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f.close()

# %%
f=open('dev/frog_song.txt','w', encoding='utf-8')
f.write('개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n삘릴리 개굴개굴 삘릴리리\n삘릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n')
f.close()

# %%
f=open('dev/frog_song.txt','w', encoding='utf-8')
data = ['개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n삘릴리 개굴개굴 삘릴리리\n삘릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n']
f.writelines(data)

# %%
# 상대경로
f=open('dev/frog_song.txt','r',encoding='utf-8')
# 절대경로
# f=open('C:/Users/Playdata/python/python_basic/17_fileIO/dev/frog_song.txt','r',encoding='utf-8')

data= f.read()
print(data)
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# 삘릴리 개굴개굴 삘릴리리
# 삘릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f.close()

# %%
f = open("dev/frog_song.txt","r",encoding='utf-8')

line=f.readline()
print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바

# %%
f = open("dev/frog_song.txt","r",encoding='utf-8')

while True : 
    line = f.readline()
    
    if not line:
        break
    
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f=open('dev/frog_song.txt','r',encoding='utf-8')

line = f.readlines()
print(line)

f.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[57], line 3
#       1 f=open('dev/frog_song.txt','r',encoding='utf-8')
# ----> 3 line = f.readlines()
#       4 print(line)
#       6 f.close()
#
# File <frozen codecs>:325, in BufferedIncrementalDecoder.decode(self, input, final)
#     322 def decode(self, input, final=False):
#     323     # decode input (taking the buffer into account)
#     324     data = self.buffer + input
# --> 325     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     326     # keep undecoded input until the next call
#     327     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb3 in position 11: invalid start byte

# %%
f=open('dev/frog_song.txt','r',encoding='utf-8')

lines = f.readlines()
for line in lines:
    print(line)
    
f.close()
# Out:
# 노래 끝!

# %%
f=open('dev/frog_song.txt','r',encoding='utf-8')

for line in f:
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# 삘릴리 개굴개굴 삘릴리리
#
# 삘릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
# 절대경로
# with open("C:/Users/Playdata/python/python_basic/17_fileIO/new/fi/le/frog_song.txt", "w") as f:
#     f.write("Life is too short, you need python")
# 상대경로
with open("new/fi/le/frog_song.txt", "w") as f:
    f.write("Life is too short, you need python")
